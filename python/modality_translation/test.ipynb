# %%
import torch
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt

PATH = "/scratch/govind/modality_translation/DREAMBOOTH_OUT"

pipe = StableDiffusionPipeline.from_pretrained(PATH).to("cuda")
# Out:
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 12.10it/s]

# %%
prompt = "a photo of sks road"

image = pipe(prompt).images[0]

image
# Out:
# ...
# 100%|██████████| 50/50 [00:06<00:00,  7.90it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
