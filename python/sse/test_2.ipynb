# %%
import asyncio
import nest_asyncio
from mcp import ClientSession
from mcp.client.sse import sse_client

nest_asyncio.apply()


async def main():
    # Connect to the server using SSE
    async with sse_client("http://localhost:32911/sse") as (read_stream, write_stream):
        async with ClientSession(read_stream, write_stream) as session:
            # Initialize the connection
            await session.initialize()

            # List available tools
            tools_result = await session.list_tools()
            print("Available tools:")
            for tool in tools_result.tools:
                print(f"  - {tool.name}: {tool.description}")

            # Call our calculator tool
            result = await session.call_tool("add", arguments={"num_1": 2, "num_2": 3})
            print(f"2 + 3 = {result.content[0].text}")


if __name__ == "__main__":
    asyncio.run(main())
# Out:
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3549, in run_code
#   |     exec(code_obj, self.user_global_ns, self.user_ns)
#   |     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "/tmp/ipykernel_129888/875715078.py", line 28, in <module>
#   |     asyncio.run(main())
#   |     ~~~~~~~~~~~^^^^^^^^
#   |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/nest_asyncio.py", line 30, in run
#   |     return loop.run_until_complete(task)
#   |            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/nest_asyncio.py", line 98, in run_until_complete
#   |     return f.result()
#   |            ~~~~~~~~^^
#   |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/asyncio/futures.py", line 199, in result
#   |     raise self._exception.with_traceback(self._exception_tb)
#   |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/asyncio/tasks.py", line 304, in __step_run_and_handle_result
#   |     result = coro.send(None)
#   |   File "/tmp/ipykernel_129888/875715078.py", line 11, in main
#   |     async with sse_client("http://localhost:32911/sse") as (read_stream, write_stream):
#   |                ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/contextlib.py", line 214, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/mcp/client/sse.py", line 43, in sse_client
#   |     async with anyio.create_task_group() as tg:
#   |                ~~~~~~~~~~~~~~~~~~~~~~~^^
#   |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/anyio/_backends/_asyncio.py", line 772, in __aexit__
#   |     raise BaseExceptionGroup(
#   |         "unhandled errors in a TaskGroup", self._exceptions
#   |     ) from None
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_transports/default.py", line 101, in map_httpcore_exceptions
#     |     yield
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_transports/default.py", line 394, in handle_async_request
#     |     resp = await self._pool.handle_async_request(req)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_async/connection_pool.py", line 216, in handle_async_request
#     |     raise exc from None
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_async/connection_pool.py", line 196, in handle_async_request
#     |     response = await connection.handle_async_request(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |         pool_request.request
#     |         ^^^^^^^^^^^^^^^^^^^^
#     |     )
#     |     ^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_async/connection.py", line 101, in handle_async_request
#     |     return await self._connection.handle_async_request(request)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_async/http11.py", line 143, in handle_async_request
#     |     raise exc
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_async/http11.py", line 113, in handle_async_request
#     |     ) = await self._receive_response_headers(**kwargs)
#     |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_async/http11.py", line 186, in _receive_response_headers
#     |     event = await self._receive_event(timeout=timeout)
#     |             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_async/http11.py", line 224, in _receive_event
#     |     data = await self._network_stream.read(
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |         self.READ_NUM_BYTES, timeout=timeout
#     |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     )
#     |     ^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_backends/anyio.py", line 32, in read
#     |     with map_exceptions(exc_map):
#     |          ~~~~~~~~~~~~~~^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/contextlib.py", line 162, in __exit__
#     |     self.gen.throw(value)
#     |     ~~~~~~~~~~~~~~^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpcore/_exceptions.py", line 14, in map_exceptions
#     |     raise to_exc(exc) from exc
#     | httpcore.ReadError
#     |
#     | The above exception was the direct cause of the following exception:
#     |
#     | Traceback (most recent call last):
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/mcp/client/sse.py", line 47, in sse_client
#     |     async with aconnect_sse(
#     |                ~~~~~~~~~~~~^
#     |         client,
#     |         ^^^^^^^
#     |     ...<2 lines>...
#     |         timeout=httpx.Timeout(timeout, read=sse_read_timeout),
#     |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ) as event_source:
#     |     ^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/contextlib.py", line 214, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx_sse/_api.py", line 69, in aconnect_sse
#     |     async with client.stream(method, url, headers=headers, **kwargs) as response:
#     |                ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/contextlib.py", line 214, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_client.py", line 1583, in stream
#     |     response = await self.send(
#     |                ^^^^^^^^^^^^^^^^
#     |     ...<4 lines>...
#     |     )
#     |     ^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_client.py", line 1629, in send
#     |     response = await self._send_handling_auth(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ...<4 lines>...
#     |     )
#     |     ^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_client.py", line 1657, in _send_handling_auth
#     |     response = await self._send_handling_redirects(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |     ...<3 lines>...
#     |     )
#     |     ^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_client.py", line 1694, in _send_handling_redirects
#     |     response = await self._send_single_request(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_client.py", line 1730, in _send_single_request
#     |     response = await transport.handle_async_request(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_transports/default.py", line 393, in handle_async_request
#     |     with map_httpcore_exceptions():
#     |          ~~~~~~~~~~~~~~~~~~~~~~~^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/contextlib.py", line 162, in __exit__
#     |     self.gen.throw(value)
#     |     ~~~~~~~~~~~~~~^^^^^^^
#     |   File "/home/fidgetsinner/.conda/envs/inspectai/lib/python3.13/site-packages/httpx/_transports/default.py", line 118, in map_httpcore_exceptions
#     |     raise mapped_exc(message) from exc
#     | httpx.ReadError
#     +------------------------------------
