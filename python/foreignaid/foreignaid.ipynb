# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('explorer_obligations_2022.csv')

# %%
df.sort_values(by='current_amount', ascending=False).head(20)
# Out:
#     country_id country_code               country_name  region_id  \
# 0          804          UKR                    Ukraine          2
# 1          376          ISR                     Israel          3
# 2         1002          WLD                      World          7
# 3         1002          WLD                      World          7
# 4          804          UKR                    Ukraine          2
# 5          804          UKR                    Ukraine          2
# 6          818          EGY                      Egypt          3
# 7         1002          WLD                      World          7
# 8          804          UKR                    Ukraine          2
# 9         1002          WLD                      World          7
# 10        1002          WLD                      World          7
# 11         804          UKR                    Ukraine          2
# 12         400          JOR                     Jordan          3
# ...

# %%
sns.barplot(data=df.sort_values(by='current_amount', ascending=False).head(100), x='current_amount', y='country_name')
# Out:
# <Axes: xlabel='current_amount', ylabel='country_name'>
