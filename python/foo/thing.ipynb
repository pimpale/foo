# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
threelayernet = nn.Sequential(
    nn.Linear(2, 4),
    nn.ReLU(),
    nn.Linear(4, 4),
    nn.ReLU(),
    nn.Linear(4, 1)
)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
training_data = torch.tensor([[1, 0], [2, 0], [3, 1], [4, 1]], dtype=torch.float32)

targets = torch.tensor([[0], [1], [2], [3]], dtype=torch.float32)

# %%
# training loop
optimizer = torch.optim.SGD(threelayernet.parameters(), lr=0.01)
for epoch in range(1000):
    optimizer.zero_grad()
    output = threelayernet(training_data)
    loss = F.mse_loss(output, targets)
    loss.backward()
    optimizer.step()
    print(f"epoch {epoch}: loss {loss.item()}")
# Out:
# epoch 0: loss 4.469139099121094
# epoch 1: loss 4.252053737640381
# epoch 2: loss 4.048266410827637
# epoch 3: loss 3.8567280769348145
# epoch 4: loss 3.6765410900115967
# epoch 5: loss 3.50693416595459
# epoch 6: loss 3.3472390174865723
# epoch 7: loss 3.196869373321533
# epoch 8: loss 3.055309295654297
# epoch 9: loss 2.9220991134643555
# epoch 10: loss 2.796823024749756
# epoch 11: loss 2.6791038513183594
# epoch 12: loss 2.5685925483703613
# epoch 13: loss 2.46496319770813
# epoch 14: loss 2.3679087162017822
# epoch 15: loss 2.27713680267334
# epoch 16: loss 2.1923646926879883
# epoch 17: loss 2.1133198738098145
# epoch 18: loss 2.0397355556488037
# epoch 19: loss 1.9713512659072876
# epoch 20: loss 1.9079105854034424
# epoch 21: loss 1.8491618633270264
# epoch 22: loss 1.794857144355774
# epoch 23: loss 1.744752287864685
# epoch 24: loss 1.6986087560653687
# epoch 25: loss 1.6561917066574097
# epoch 26: loss 1.6172723770141602
# epoch 27: loss 1.5816280841827393
# ...
