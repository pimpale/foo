# %%
from gradio_client import Client
import pandas as pd
import numpy as np
from sklearn import datasets, decomposition
import matplotlib.pyplot as plt

# %%
client = Client("open-llm-leaderboard/open_llm_leaderboard")
result = client.predict(
		api_name="/get_latest_data_leaderboard"
)

# %%
df = pd.DataFrame(result["data"], columns=result["headers"])

# %%
df
# Out:
#      T                                              Model  Average ⬆️  IFEval  \
# 0    💬  <a target="_blank" href="https://huggingface.c...       44.75   79.96
# 1    💬  <a target="_blank" href="https://huggingface.c...       43.61   81.63
# 2    💬  <a target="_blank" href="https://huggingface.c...       43.40   80.08
# 3    💬  <a target="_blank" href="https://huggingface.c...       42.49   79.89
# 4    💬  <a target="_blank" href="https://huggingface.c...       42.17   76.06
# ..  ..                                                ...         ...     ...
# 521  🟢  <a target="_blank" href="https://huggingface.c...        1.66    0.00
# 522  🟢  <a target="_blank" href="https://huggingface.c...        1.66    0.00
# 523  🟢  <a target="_blank" href="https://huggingface.c...        1.66    0.00
# 524  🟢  <a target="_blank" href="https://huggingface.c...        1.66    0.00
# 525  🔶  <a target="_blank" href="https://huggingface.c...        1.41    1.11
#
# ...

# %%
df.columns
# Out:
# Index(['T', 'Model', 'Average ⬆️', 'IFEval', 'IFEval Raw', 'BBH', 'BBH Raw',
#        'MATH Lvl 5', 'MATH Lvl 5 Raw', 'GPQA', 'GPQA Raw', 'MUSR', 'MUSR Raw',
#        'MMLU-PRO', 'MMLU-PRO Raw', 'Type', 'Architecture', 'Weight type',
#        'Precision', 'Not_Merged', 'Hub License', '#Params (B)', 'Hub ❤️',
#        'Available on the hub', 'Model sha', 'Flagged', 'MoE',
#        'Submission Date', 'Upload To Hub Date', 'Chat Template',
#        'Maintainer's Highlight', 'fullname'],
#       dtype='object')

# %%
df[df["Maintainer's Highlight"] == True]
# Out:
#      T                                              Model  Average ⬆️  IFEval  \
# 3    💬  <a target="_blank" href="https://huggingface.c...       42.49   79.89
# 5    💬  <a target="_blank" href="https://huggingface.c...       41.08   78.25
# 13   💬  <a target="_blank" href="https://huggingface.c...       36.18   80.99
# 14   💬  <a target="_blank" href="https://huggingface.c...       35.97   84.28
# 19   🟢  <a target="_blank" href="https://huggingface.c...       35.13   38.24
# ..  ..                                                ...         ...     ...
# 512  🔶  <a target="_blank" href="https://huggingface.c...        3.91   16.97
# 513  🟢  <a target="_blank" href="https://huggingface.c...        3.90    6.11
# 516  🟢  <a target="_blank" href="https://huggingface.c...        3.71   13.22
# 517  🔶  <a target="_blank" href="https://huggingface.c...        3.67   10.55
# 518  🟢  <a target="_blank" href="https://huggingface.c...        3.46    6.20
#
# ...

# %%
df_raw_scores = df[['IFEval Raw', 'BBH Raw', 'MATH Lvl 5 Raw', 'GPQA Raw', 'MUSR Raw']]
df_raw_scores
# Out:
#      IFEval Raw  BBH Raw  MATH Lvl 5 Raw  GPQA Raw  MUSR Raw
# 0          0.80     0.71            0.39      0.38      0.50
# 1          0.82     0.70            0.36      0.38      0.47
# 2          0.80     0.69            0.41      0.37      0.45
# 3          0.80     0.70            0.35      0.37      0.46
# 4          0.76     0.70            0.35      0.39      0.45
# ..          ...      ...             ...       ...       ...
# 521        0.00     0.29            0.00      0.26      0.36
# 522        0.00     0.29            0.00      0.26      0.36
# 523        0.00     0.29            0.00      0.26      0.36
# 524        0.00     0.29            0.00      0.26      0.36
# 525        0.01     0.30            0.00      0.24      0.36
#
# [526 rows x 5 columns]

# %%
df_raw_scores_corr = df_raw_scores.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(df_raw_scores_corr, cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ax.set_xticks(np.arange(len(df_raw_scores_corr.columns)))
ax.set_xticklabels(df_raw_scores_corr.columns)
ax.set_yticks(np.arange(len(df_raw_scores_corr.columns)))
ax.set_yticklabels(df_raw_scores_corr.columns)
# Out:
# [Text(0, 0, 'IFEval Raw'),
#  Text(0, 1, 'BBH Raw'),
#  Text(0, 2, 'MATH Lvl 5 Raw'),
#  Text(0, 3, 'GPQA Raw'),
#  Text(0, 4, 'MUSR Raw')]

# %%
pca = decomposition.PCA(n_components=3)
pca.fit(df_raw_scores)
# Out:
# PCA(n_components=3)

# %%
pca.components_
# Out:
# array([[ 0.87998092,  0.40607356,  0.21631875,  0.09916194,  0.0641167 ],
#        [-0.46853408,  0.68873191,  0.42040915,  0.25889233,  0.24971001],
#        [-0.00507338, -0.37522852,  0.84296369, -0.0081095 , -0.38538847]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(pca.components_, cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ax.set_title("PCA Components")
ax.set_xticks([0, 1, 2, 3, 4])
ax.set_xticklabels(df_raw_scores.columns)
ax.set_yticks([0, 1, 2])
ax.set_yticklabels(["PC1", "PC2", "PC3"])
# Out:
# [Text(0, 0, 'PC1'), Text(0, 1, 'PC2'), Text(0, 2, 'PC3')]

# %%
# Explained variance
plt.bar([f"PCA{n+1}" for n in range(pca.n_components_)], pca.explained_variance_ratio_)
plt.title("Explained Variance")
plt.ylabel("Explained Variance Ratio")
# Out:
# Text(0, 0.5, 'Explained Variance Ratio')

# %%
df_raw_scores_transformed = pca.transform(df_raw_scores)
df_raw_scores_transformed
# Out:
# array([[ 0.55027034,  0.16441437,  0.15038652],
#        [ 0.55539616,  0.1280528 ,  0.14031008],
#        [ 0.54227779,  0.14397349,  0.19410089],
#        ...,
#        [-0.42950537,  0.01998818,  0.03821289],
#        [-0.42950537,  0.01998818,  0.03821289],
#        [-0.41862807,  0.01701231,  0.03457207]])

# %%
plt.hist(df[df["Maintainer's Highlight"] == True]["IFEval"], bins=20)
# Out:
# (array([ 3.,  4., 10., 24., 51., 30., 22., 12., 13.,  8., 15., 15., 16.,
#         13.,  6.,  5.,  1.,  2.,  5.,  2.]),
#  array([ 3.32 ,  7.368, 11.416, 15.464, 19.512, 23.56 , 27.608, 31.656,
#         35.704, 39.752, 43.8  , 47.848, 51.896, 55.944, 59.992, 64.04 ,
#         68.088, 72.136, 76.184, 80.232, 84.28 ]),
#  <BarContainer object of 20 artists>)
