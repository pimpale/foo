# %%
import pandas as pd

# %%
df = pd.read_csv("notable_ai_models.csv")

# %%
df.columns
# Out:
# Index(['System', 'Domain', 'Organization', 'Authors', 'Publication date',
#        'Reference', 'Link', 'Notability criteria', 'Notability criteria notes',
#        'Parameters', 'Parameters notes', 'Training compute (FLOP)',
#        'Training compute notes', 'Training dataset',
#        'Training dataset size (datapoints)', 'Dataset size notes', 'Abstract',
#        'Confidence', 'Epochs', 'Model accessibility',
#        'Country (from Organization)', 'Organization categorization',
#        'Training dataset notes', 'Training time (hours)',
#        'Training time notes', 'Training hardware', 'Finetune compute notes',
#        'Hardware quantity', 'Hardware utilization', 'Base model', 'Citations',
#        'Compute cost notes', 'Finetune compute (FLOP)',
#        'Training compute cost (2023 USD)', 'Batch size', 'Batch size notes'],
#       dtype='object')

# %%
df
# Out:
#                                  System  \
# 0                            ESM3 (98B)
# 1                DeepSeek-Coder-V2-236B
# 2                       Nemotron-4 340B
# 3                                GPT-4o
# 4                           Llama 3-70B
# ..                                  ...
# 820  Sequence-based pattern recognition
# 821              Self Organizing System
# 822                   Genetic algorithm
# 823                               SNARC
# 824                             Theseus
#
#                                       Domain  \
# 0                                    Biology
# 1                                   Language
# 2                                   Language
# 3    Multimodal,Language,Audio,Speech,Vision
# 4                                   Language
# ..                                       ...
# 820                                   Vision
# 821                                    Other
# 822                                    Other
# ...

# %%
df["System"]
# Out:
# 0                              ESM3 (98B)
# 1                  DeepSeek-Coder-V2-236B
# 2                         Nemotron-4 340B
# 3                                  GPT-4o
# 4                             Llama 3-70B
#                       ...
# 820    Sequence-based pattern recognition
# 821                Self Organizing System
# 822                     Genetic algorithm
# 823                                 SNARC
# 824                               Theseus
# Name: System, Length: 825, dtype: object

# %%
df["Parameters"]
# Out:
# 0      9.800000e+10
# 1      2.360000e+11
# 2      3.400000e+11
# 3               NaN
# 4      7.000000e+10
#            ...
# 820             NaN
# 821    2.250000e+02
# 822             NaN
# 823    4.000000e+01
# 824    4.000000e+01
# Name: Parameters, Length: 825, dtype: float64

# %%
df["Training compute (FLOP)"]
# Out:
# 0      1.070000e+24
# 1      1.285200e+24
# 2      1.800000e+25
# 3               NaN
# 4      6.300000e+24
#            ...
# 820             NaN
# 821             NaN
# 822             NaN
# 823             NaN
# 824    4.000000e+01
# Name: Training compute (FLOP), Length: 825, dtype: float64

# %%
models = [
    "gpt-4",
    "claude-2",
    "claude",
    "gpt-3.5-turbo",
    "text-davinci-003",
    "claude-instant",
    "chat-bison-001",
    "text-davinci-002",
    "llama-2-70b",
    "guanaco-65b",
    "codellama-34b",
    "vicuna-33b",
    "wizardlm-30b",
    "guanaco-33b",
    "vicuna-13b",
    "llama-2-13b",
    "openchat-13b",
    "wizardlm-13b",
    "vicuna-7b",
    "codellama-13b",
    "codellama-7b",
    "koala-13b",
    "llama-2-7b",
    "codegeex2-6b",
    "dolly-12b",
    "chatglm-6b",
    "oasst-12b",
]

# %%
model_data = df[df["System"].transform(lambda x: x.lower()).isin(models)]

# %%
model_data
# Out:
#      System                                       Domain Organization  \
# 100   GPT-4  Multimodal,Language,Vision,Image generation       OpenAI
# 102  Claude                                     Language    Anthropic
#
#                                                Authors Publication date  \
# 100  OpenAI, Josh Achiam, Steven Adler, Sandhini Ag...       2023-03-15
# 102                                                NaN       2023-03-14
#
#                   Reference  \
# 100  GPT-4 Technical Report
# 102      Introducing Claude
#
#                                                   Link  \
# 100                   https://arxiv.org/abs/2303.08774
# 102  https://www.anthropic.com/index/introducing-cl...
#
#                              Notability criteria  \
# 100  Highly cited,SOTA improvement,Training cost
# 102     Historical significance,SOTA improvement
#
#                              Notability criteria notes  Parameters  ...  \
# ...
