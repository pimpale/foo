# %%
import geopandas as gpd
import os

# %%
# Read in the shapefile
PATH = '~/nuplan_maps/maps/sg-one-north/9.17.1964/map.gpkg'
path = os.path.expanduser(PATH)

gdf = gpd.read_file(path, layer="meta")

# %%
gdf.head()
# Out:
#                      key       value geometry
# 0      X-map_cli-version      9.17.0     None
# 1  geographicCoordSystem   epsg:4326     None
# 2   projectedCoordSystem  epsg:32648     None

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.head(100).plot()
# Out:
# <Axes: >
